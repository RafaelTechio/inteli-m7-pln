# %% [markdown]
# A probabilidade, utilizando regressão logística, de o sentimento ser 1 para os pontos P(2,3) e P(3,0) respectivamente são:
#
# Probabilidade de P(2,3): 0.23665804677778646
# Probabilidade de P(3,0): 0.8057062555966683

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import matplotlib.pyplot as plt

# %%
train_data = pd.DataFrame({
'Produto': ['P1', 'P2', 'P3', 'P4', 'P5'],
'#Palavras Positivas': [5, 3, 6, 1, 4],
'#Palavras Negativas': [1, 3, 2, 5, 2],
'Sentimento': [1, 0, 1, 0, 1]
})

train_data
# Out:
#   Produto  #Palavras Positivas  #Palavras Negativas  Sentimento
# 0      P1                    5                    1           1
# 1      P2                    3                    3           0
# 2      P3                    6                    2           1
# 3      P4                    1                    5           0
# 4      P5                    4                    2           1

# %%
X = train_data[['#Palavras Positivas', '#Palavras Negativas']]
y = train_data['Sentimento']

print(X)
print("================")
print(y)
# Out:
#    #Palavras Positivas  #Palavras Negativas
# 0                    5                    1
# 1                    3                    3
# 2                    6                    2
# 3                    1                    5
# 4                    4                    2
# ...
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Sentimento, dtype: int64

# %%
model = LogisticRegression()
model.fit(X, y)

print("Intercepto:", intercepto)
print("Coeficientes:", coeficientes)
# Out:
# Intercepto: [-0.86686473]
# Coeficientes: [[ 0.76307093 -0.61012233]]

# %%
def logit_func(x1, x2):
  return modelo.intercept_[0] + modelo.coef_[0][0] * x1 + modelo.coef_[0][1] * x2
def sigmoid(x):
  return 1 / (1 + np.exp(-x))

def get_probability(x1, x2):
  return sigmoid(logit_func(x1,x2))

# %%
print('Probabilidade de P(2,3): ', get_probability(2,3))
print('Probabilidade de P(3,0): ', get_probability(3,0))
# Out:
# Probabilidade de P(2,3):  0.23665804677778646
# Probabilidade de P(3,0):  0.8057062555966683
